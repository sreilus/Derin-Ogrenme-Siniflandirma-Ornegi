# %%
import keras
keras.__version__
# Out:
# Using TensorFlow backend.
# '2.2.4'

# %%
import os, shutil

# %%
# Orijinal verisetinin bulunduğu dizine giden yol 
# veri kümesi sıkıştırılmamış
original_dataset_dir = 'c:\\Users\\Muhammet\\Desktop\\veriseti'


# daha küçük veri setimizi saklıyoruz
base_dir = 'C:\\Users\\Muhammet\\Desktop\\verisetismall'
os.mkdir(base_dir)

# Eğitimimiz,validation ve test bölümleri için klasör yollarını gösteriyoruz
train_dir = os.path.join(base_dir, 'train')
os.mkdir(train_dir)
validation_dir = os.path.join(base_dir, 'validation')
os.mkdir(validation_dir)
test_dir = os.path.join(base_dir, 'test')
os.mkdir(test_dir)

# Şise için eğitim resimlerinin klasörünü gösteriyoruz
train_siseler_dir = os.path.join(train_dir, 'sise')
os.mkdir(train_siseler_dir)

# Silgi için eğitim resimlerinin klasörünü gösteriyoruz
train_silgiler_dir = os.path.join(train_dir, 'silgi')
os.mkdir(train_silgiler_dir)

# Şise için validation resimlerinin klasörünü gösteriyoruz
validation_siseler_dir = os.path.join(validation_dir, 'sise')
os.mkdir(validation_siseler_dir)

# Silgi için validation resimlerinin klasörünü gösteriyoruz
validation_silgiler_dir = os.path.join(validation_dir, 'silgi')
os.mkdir(validation_silgiler_dir)

# Şise için test resimlerinin klasörünü gösteriyoruz
test_siseler_dir = os.path.join(test_dir, 'sise')
os.mkdir(test_siseler_dir)

# Silgi için test resimlerinin klasörünü gösteriyoruz
test_silgiler_dir = os.path.join(test_dir, 'silgi')
os.mkdir(test_silgiler_dir)

#train_siseler klasörüne ilk 50 şişe resmini kopyalıyor
fnames = ['sise.{}.jpg'.format(i) for i in range(50)]
for fname in fnames:
    src = os.path.join(original_dataset_dir, fname)
    dst = os.path.join(train_siseler_dir, fname)
    shutil.copyfile(src, dst)

#validation_siseler klasörüne sonraki 25 şişe resmini kopyalıyor
fnames = ['sise.{}.jpg'.format(i) for i in range(50, 75)]
for fname in fnames:
    src = os.path.join(original_dataset_dir, fname)
    dst = os.path.join(validation_siseler_dir, fname)
    shutil.copyfile(src, dst)
    
#test_siseler klasörüne sonraki 25 şişe resmini kopyalıyor
fnames = ['sise.{}.jpg'.format(i) for i in range(75, 100)]
for fname in fnames:
    src = os.path.join(original_dataset_dir, fname)
    dst = os.path.join(test_siseler_dir, fname)
    shutil.copyfile(src, dst)
    
#train_siseler klasörüne ilk 50 silgi resmini kopyalıyor
fnames = ['silgi.{}.jpg'.format(i) for i in range(50)]
for fname in fnames:
    src = os.path.join(original_dataset_dir, fname)
    dst = os.path.join(train_silgiler_dir, fname)
    shutil.copyfile(src, dst)
    
#validation_siseler klasörüne sonraki 25 silgi resmini kopyalıyor
fnames = ['silgi.{}.jpg'.format(i) for i in range(50, 75)]
for fname in fnames:
    src = os.path.join(original_dataset_dir, fname)
    dst = os.path.join(validation_silgiler_dir, fname)
    shutil.copyfile(src, dst)
#test_siseler klasörüne sonraki 25 silgi resmini kopyalıyor
fnames = ['silgi.{}.jpg'.format(i) for i in range(75, 100)]
for fname in fnames:
    src = os.path.join(original_dataset_dir, fname)
    dst = os.path.join(test_silgiler_dir
                       , fname)
    shutil.copyfile(src, dst)

# %%
print('eğitim için toplam şişe sayısı:', len(os.listdir(train_siseler_dir)))
# Out:
# eğitim için toplam şişe sayısı: 50

# %%
print('eğitim için toplam silgi sayısı:', len(os.listdir(train_silgiler_dir)))
# Out:
# eğitim için toplam silgi sayısı: 50

# %%
print('validation için toplam sise sayısı:', len(os.listdir(validation_siseler_dir)))
# Out:
# validation için toplam sise sayısı: 25

# %%
print('validation için toplam silgi sayısı:', len(os.listdir(validation_silgiler_dir)))
# Out:
# validation için toplam silgi sayısı: 25

# %%
print('test için toplam sise sayısı:', len(os.listdir(test_siseler_dir)))
# Out:
# test için toplam sise sayısı: 25

# %%
print('test için toplam silgi sayısı:', len(os.listdir(test_silgiler_dir)))
# Out:
# test için toplam silgi sayısı: 25

# %%
from keras import layers
from keras import models

model = models.Sequential()
model.add(layers.Conv2D(32, (3, 3), activation='relu',
                        input_shape=(150, 150, 3)))
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Conv2D(64, (3, 3), activation='relu'))
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Conv2D(128, (3, 3), activation='relu'))
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Conv2D(128, (3, 3), activation='relu'))
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Flatten())
model.add(layers.Dense(512, activation='relu'))
model.add(layers.Dense(1, activation='sigmoid'))
# Out:
# Using TensorFlow backend.
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ModuleNotFoundError: No module named 'numpy.core._multiarray_umath'
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# ImportError: numpy.core.multiarray failed to import
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# ~\Anaconda3\lib\importlib\_bootstrap.py in _find_and_load(name, import_)
#
# SystemError: <class '_frozen_importlib._ModuleLockManager'> returned a result with an error set
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# ...

# %%
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# conv2d_1 (Conv2D)            (None, 148, 148, 32)      896
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 74, 74, 32)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 72, 72, 64)        18496
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 36, 36, 64)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 34, 34, 128)       73856
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 17, 17, 128)       0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 15, 15, 128)       147584
# ...

# %%
from keras import optimizers

model.compile(loss='binary_crossentropy',
              optimizer=optimizers.RMSprop(lr=1e-4),
              metrics=['acc'])

# %%
from keras.preprocessing.image import ImageDataGenerator

train_datagen = ImageDataGenerator(rescale=1./255)
test_datagen = ImageDataGenerator(rescale=1./255)

train_generator = train_datagen.flow_from_directory(
        train_dir,
        target_size=(150, 150),
        batch_size=20,
        class_mode='binary')

validation_generator = test_datagen.flow_from_directory(
        validation_dir,
        target_size=(150, 150),
        batch_size=20,
        class_mode='binary')
# Out:
# Found 100 images belonging to 2 classes.
# Found 50 images belonging to 2 classes.

# %%
print("basladi")
import sys
from PIL import Image
sys.modules['Image'] = Image 
for data_batch, labels_batch in train_generator:
    print('data batch shape:', data_batch.shape)
    print('labels batch shape:', labels_batch.shape)
    break
# Out:
# basladi
# data batch shape: (20, 150, 150, 3)
# labels batch shape: (20,)

# %%
history = model.fit_generator(
      train_generator,
      steps_per_epoch=100,
      epochs=20,
      validation_data=validation_generator,
      validation_steps=50)
# Out:
# Epoch 1/20
# ---------------------------------------------------------------------------
# InternalError                             Traceback (most recent call last)
# <ipython-input-24-84c1eb29e39c> in <module>
#       4       epochs=20,
#       5       validation_data=validation_generator,
# ----> 6       validation_steps=50)
#
# ~\Anaconda3\envs\tensorflow-gpu\lib\site-packages\keras\legacy\interfaces.py in wrapper(*args, **kwargs)
#      89                 warnings.warn('Update your `' + object_name + '` call to the ' +
#      90                               'Keras 2 API: ' + signature, stacklevel=2)
# ---> 91             return func(*args, **kwargs)
#      92         wrapper._original_function = func
#      93         return wrapper
#
# ...

# %%
model.save('silgi_sise_small_3.h5')

# %%
# %matplotlib inline

import matplotlib.pyplot as plt
import matplotlib


acc = history.history['acc']
val_acc = history.history['val_acc']
loss = history.history['loss']
val_loss = history.history['val_loss']

epochs = range(len(acc))

plt.plot(epochs, acc, 'bo', label='Training acc')
plt.plot(epochs, val_acc, 'b', label='Validation acc')
plt.title('Training and validation accuracy')
plt.legend()

plt.figure()

plt.plot(epochs, loss, 'bo', label='Training loss')
plt.plot(epochs, val_loss, 'b', label='Validation loss')
plt.title('Training and validation loss')
plt.legend()

plt.show()

# %%
datagen = ImageDataGenerator(
      rotation_range=40, #resmin açısını değiştirir
      width_shift_range=0.2, # resmi sağ sola kaydırır
      height_shift_range=0.2, # resmi yukarı kaydırır
      shear_range=0.2, #: Kayan nokta. Kesme Yoğunluğu (Saat yönünün tersine derece olarak kesme açısı)
      zoom_range=0.2, 
      horizontal_flip=True, # resmi ters çeviriyor
      fill_mode='nearest' #Girişin sınırları dışındaki noktalar verilen moda göre doldurulur )

# %%
from keras.preprocessing import image

fnames = [os.path.join(train_siseler_dir, fname) for fname in os.listdir(train_siseler_dir)]

img_path = fnames[3]

img = image.load_img(img_path, target_size=(150, 150))

x = image.img_to_array(img)


x = x.reshape((1,) + x.shape)
i = 0

for batch in datagen.flow(x, batch_size=1):
    plt.figure(i)
    imgplot = plt.imshow(image.array_to_img(batch[0]))
    i += 1
    if i % 4 == 0:
        break

plt.show()

# %%
model = models.Sequential()
model.add(layers.Conv2D(32, (3, 3), activation='relu',
                        input_shape=(150, 150, 3)))
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Conv2D(64, (3, 3), activation='relu'))
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Conv2D(128, (3, 3), activation='relu'))
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Conv2D(128, (3, 3), activation='relu'))
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Flatten())
model.add(layers.Dropout(0.7))
model.add(layers.Dense(512, activation='relu'))
model.add(layers.Dense(1, activation='sigmoid'))

model.compile(loss='binary_crossentropy',
              optimizer=optimizers.RMSprop(lr=1e-4),
              metrics=['acc'])

# %%
import tensorflow as tf
train_datagen = ImageDataGenerator(
    rescale=1./255,
    rotation_range=40,
    width_shift_range=0.3,
    height_shift_range=0.3,
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True,)

test_datagen = ImageDataGenerator(rescale=1./255)

train_generator = train_datagen.flow_from_directory(
        train_dir,
        target_size=(150, 150),
        batch_size=32,
        class_mode='binary')

validation_generator = test_datagen.flow_from_directory(
        validation_dir,
        target_size=(150, 150),
        batch_size=32,
        class_mode='binary')

history = model.fit_generator(
      train_generator,
      steps_per_epoch=100,
      epochs=30,
      validation_data=validation_generator,
      validation_steps=50)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-fb567998aa4f> in <module>
#       1 import tensorflow as tf
# ----> 2 train_datagen = ImageDataGenerator(
#       3     rescale=1./255,
#       4     rotation_range=40,
#       5     width_shift_range=0.3,
#
# NameError: name 'ImageDataGenerator' is not defined

# %%
model.save('silgi_ve_sise_small_4.h5')

# %%
acc = history.history['acc']
val_acc = history.history['val_acc']
loss = history.history['loss']
val_loss = history.history['val_loss']

epochs = range(len(acc))

plt.plot(epochs, acc, 'bo', label='Training acc')
plt.plot(epochs, val_acc, 'b', label='Validation acc')
plt.title('Training and validation accuracy')
plt.legend()

plt.figure()

plt.plot(epochs, loss, 'bo', label='Training loss')
plt.plot(epochs, val_loss, 'b', label='Validation loss')
plt.title('Training and validation loss')
plt.legend()

plt.show()
